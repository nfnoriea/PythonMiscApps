# %% [markdown]
# # IBC Protocol Analyzer API

# %% [markdown]
# ## <span style="color:blue"> Agents Module </span>
#
# ### General Functions
#  - create_safety_data(data)
#  - create_agents(path)
#
# ### Safety_Info Class
# ##### Safety_Info( ppe, safety_eq, spill, addlpractice, surface_de, equip_de, waste)
# #### Functions
#   - get_info()
#
# ### AgentList Class
# This is a simple dictionary of all Agents where each key represents a list of Agent Objects of the selected key type
#
# [Microbe, VV, Toxin, VTC, TFC, IP, TAT, DNA, CC, HM, NHPM, OM, Other]
#
# ### Agent Superclass
# ##### Agent( name, atype, safety, admin)
# #### Functions
#    - get_safety_info()
#    - get_name()
#    - get_type()
#    - is_administered()
#    - get_info() <span style="color:Red"> Overloaded </span>
#
# # Agent Subclass Additional Variables
#  - Microbe (rg, sa, abx, attenuate)
#  - VV (rg, sa, attenuate, rc)
#  - Toxin (sa, stored_lab)
#  - VTC (dna, dna_func, obtained, test_method, system, hazards)
#  - TFC (dna, dna_func)
#  - IP
#  - TAT
#  - DNA (promoter, drug_res, hosts, cell types, transfect)
#  - CCells
#  - HM (irb)
#  - NHPM
#  - OM
#  - Other(bsl, desc)

# %% [markdown]
# ## <span style="color:Blue"> DNA Module</span>
#
# ### Gene Class
# ##### Gene( name, func, derive, onco)
# #### Functions
#   - create_genes(path)

# %% [markdown]
# ## <span style="color:Blue"> Animal Module </span>
#
# ### Animal Class
# ##### Animal ( name, iacuc, shed, route, absl, transport, freq, total_doses, max_dose, animal_species)
# #### Functions
#  - create_animals(path)

# %% [markdown]
# ## <span style="color:Blue"> Location Module </span>
#
# #### General Functions
# - create_locations(path) - _Returns a list of Rooms and BSCs_
# - process_bscs(data, rooms) - _Returns a list of BSC objects_
# - process_rooms(data) - _Returns a List of Room Objects_
#
# ### Room Class
# ##### Room ( bldg, room_num, use)
#
# #### Functions
#  - get_info()
#
# ### BSC Class
# ##### BSC( btype, manufacturer, model_num, serial_num, cert_date, room)
# #### Functions
#  - get_info()

# %% [markdown]
# ## <span style="color:Blue"> Protocol Module </span>
#
# #### General Functions
# - create_protocol(path) -  _Returns a Protocol Object_
#
# ### Protocol Class
#
# - id
# - name
# - pi
# - risks
# - special_risks
# - durc
# - agent_list
# - genes
# - rooms
# - cabinets
# - animals
#
# #### Variables
#  - durc    - _list of all DURC inidcators as bools_
#  - risks   - _list of all agents on protocol as bools_
#  - special_risks    - _list of all special indicators (Human Use, Animal Use, N/A Use, Large Scale, Environmental Release, Genome Editing)_
#
# #### Functions
# - get_agentlist()
# - get_genes()
# - get_rooms()
# - get_cabinets()
# - get_animals()
# - print_durc()
# - get_info() - _Print Protocol ID, Name, PI, DURC, Risks, Spec. Risks_
# - print_all() - _Print Agents, DNA, Rooms, BSCs, Animals_
# - print_agent_nums() - _Print Agent Numbers
# - print_agents(atype) - _Print Specific Type of Agents if argument given, else print all agents_

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns',60)
from lib import protocol

# %%
p = protocol.create_protocol('./test_data/1287/')

# %%
p.print_all()
# Out:
# ****
# ALL AGENTS
# ****
#
# Agents
# ( Bacteria )    E. coli K12 or similar
# SA?  N 	RG:  RG1
# Attenuated?  No Data
# Abx Profile? No Data
# Admin H/A? N
#
# ( Viral Vector )    Lentiviral vector Lentivirinae
# SA?  N 	RG:  RG2
# Attenuated?  Y
# Replication Competent?  N
# Admin H/A? N
#
# ( Viral Vector )    Murine Retrovirus - Ecotropic
# SA?  N 	RG:  RG1
# Attenuated?  N
# Replication Competent?  N
# Admin H/A? N
#
# ( Virally Transduced Cells )    Human hematopoietic cell lines and fibroblast cell lines
# DNA:  Library contains all genes including all known oncogenes and tumor suppressors or shRNA targeting those genes
# Vector System:  Lentivirus
# DNA Function:  Regulation of differentiation and cell growth.
# Obtained from Others?  N
# Testing Method:  Serial transfer and p24 ELISA assay will be performed for RCV every 6 months for routine cell culture and every batch preparation of viral supernatant for in vivo use.
# Potential Hazards:  There is the potential for the gene to cause integration and transformation.
# Admin H/A? N
#
# ( Virally Transduced Cells )    Murine hematopoietic and fibroblast cell lines
# DNA:  A library of all genes, including known oncogenes and proto-oncogenes, or shRNA targeting those genes
# Vector System:  Lentivirus and/or Retrovirus
# DNA Function:  Regulation of differentiation and cell growth.
# Obtained from Others?  N
# Testing Method:  The ecotropic retrovirus does not require testing.The lentivirus will be tested by serial transfer and p24 ELISA assay will be performed for RCV every 6 months for routine cell culture and every batch preparation of viral supernatant for in vivo use.
# Potential Hazards:  There is the potential for the lentivirus to integrate and cause transformation.
# Admin H/A? N
#
# ( Virally Transduced Cells )    Human primary hematopoietic cells
# DNA:  Library contains all genes including all known oncogenes and tumor suppressors or shRNA targeting those genes
# Vector System:  Lentivirus
# DNA Function:  Regulation of differentiation and cell growth.
# Obtained from Others?  N
# Testing Method:  Serial transfer and p24 ELISA assay will be performed for RCV every 6 months for routine cell culture and every batch preparation of viral supernatant for in vivo use.
# Potential Hazards:  There is the potential for the gene to cause integration and transformation.
# Admin H/A? Y
#
# ( Virally Transduced Cells )    Murine primary hematopoietic cells
# DNA:  A library of all genes, including known oncogenes and proto-oncogenes, or shRNA targeting those genes
# Vector System:  Lentivirus and/or Retrovirus
# DNA Function:  Regulation of differentiation and cell growth.
# Obtained from Others?  N
# Testing Method:  The ecotropic retrovirus does not require testing.The lentivirus will be tested by serial transfer and p24 ELISA assay will be performed for RCV every 6 months for routine cell culture and every batch preparation of viral supernatant for in vivo use.
# Potential Hazards:  There is the potential for the lentivirus to integrate and cause transformation.
# Admin H/A? Y
#
# ( Transfected Cells )    Human hematopoietic stem cells
# DNA:  CRISPR/Cas9 ribonucleoprotein particles
# DNA Function:  gene editing
# Admin H/A? Y
#
# ( Transfected Cells )    Mouse hematopoietic stem cells
# DNA:  CRISPR/Cas9 ribonucleoprotein particles
# DNA Function:  gene editing
# Admin H/A? Y
#
# ( Plasmid )    cTGM
# Promoter:  Tet-response element
# Resistance Markers:  Hygromycin
# Experiment Host:  Murine embryonic stem cells
# Transfected?  Y
# Transfected into:  Murine embryonic stem cells
# Admin H/A? N
#
# ( Plasmid )    LMN-Cherry
# Promoter:  PGK
# Resistance Markers:  Neomycin
# Experiment Host:  NIH3T3
# Transfected?  Y
# Transfected into:  NIH3T3
# Admin H/A? N
#
# ( Plasmid )    LPE
# Promoter:  LTR-Psi+
# Resistance Markers:  Puromycin
# Experiment Host:  NIH3T3 and primary murine hematopoietic cells
# Transfected?  Y
# Transfected into:  NIH3T3
# Admin H/A? N
#
# ( Plasmid )    LT3GEPIR
# Promoter:  T3G (Tet On)
# Resistance Markers:  Puromycin
# Experiment Host:  Human cells
# Transfected?  Y
# Transfected into:  K562, HeLa, HEK293T, HL60, Kasumi, Mono7, UoCM1, MonoMac, NB4, U937, ML-2, hematopoietic stem cells
# Admin H/A? N
#
# ( Plasmid )    Lv214-mCherry
# Promoter:  CMV
# Resistance Markers:  Ampicillin, mCherry
# Experiment Host:  Human cells
# Transfected?  Y
# Transfected into:  Human cells
# Admin H/A? N
#
# ( Plasmid )    PBSKII
# Promoter:  T3
# Resistance Markers:  ampicillin
# Experiment Host:  mouse fertilized egg cell
# Transfected?  N
# Admin H/A? Y
#
# ( Plasmid )    pCAGGs-FlpE
# Promoter:  Chicken beta-actin
# Resistance Markers:  Ampicillin
# Experiment Host:  Murine embryonic stem cells
# Transfected?  Y
# Transfected into:  Murine embryonic stem cells
# Admin H/A? N
#
# ( Plasmid )    pCMV-dR8.74
# Promoter:  CMV
# Resistance Markers:  Ampicillin
# Experiment Host:  HEK293T cells
# Transfected?  Y
# Transfected into:  HEK293T cells
# Admin H/A? N
#
# ( Plasmid )    pCMV-SPORT6
# Promoter:  CMV
# Resistance Markers:  Ampicillin
# Experiment Host:  E. coli
# Transfected?  N
# Admin H/A? N
#
# ( Plasmid )    pCRISPR-CG04
# Promoter:  CMV
# Resistance Markers:  Neomycin
# Experiment Host:  human and mouse hematopoietic cells and cell lines
# Transfected?  Y
# Transfected into:  human and mouse cells
# Admin H/A? N
#
# ( Plasmid )    pDONR 221
# Promoter:  None
# Resistance Markers:  Kanamycin
# Experiment Host:  E. coli
# Transfected?  Y
# Transfected into:  E. coli
# Admin H/A? N
#
# ( Plasmid )    pEZ-M17
# Promoter:  CMV
# Resistance Markers:  Puromycin
# Experiment Host:  Human and mouse hematopoietic cells and cell lines
# Transfected?  Y
# Transfected into:  Human and mouse cells
# Admin H/A? N
#
# ( Plasmid )    pGIPZ
# Promoter:  CMV
# Resistance Markers:  Puromycin
# Experiment Host:  Human cells
# Transfected?  Y
# Transfected into:  Human cells
# Admin H/A? N
#
# ( Plasmid )    pInducer20
# Promoter:  Tet-response element
# Resistance Markers:  Neomycin
# Experiment Host:  Human cells
# Transfected?  Y
# Transfected into:  Human cells
# Admin H/A? N
#
# ( Plasmid )    pMD2-VSVG
# Promoter:  CMV
# Resistance Markers:  Ampicillin
# Experiment Host:  HEK293T cells
# Transfected?  Y
# Transfected into:  HEK293T cells
# Admin H/A? N
#
# ( Plasmid )    pReceiver-M61CT
# Promoter:  CMV
# Resistance Markers:  Neomycin
# Experiment Host:  Human cells
# Transfected?  Y
# Transfected into:  Human cells
# Admin H/A? N
#
# ( Plasmid )    pReciever-M17-GFP
# Promoter:  CMV
# Resistance Markers:  Puromycin
# Experiment Host:  Human and mouse hematopoietic cells and cell lines
# Transfected?  Y
# Transfected into:  Human and mouse cells
# Admin H/A? N
#
# ( Plasmid )    pX330-U6-Chimeric_BB-CBh-hSpCas9
# Promoter:  CBh
# Resistance Markers:  None
# Experiment Host:  human and mouse hematopoietic cells and cell lines
# Transfected?  Y
# Transfected into:  human and mouse cells
# Admin H/A? N
#
# ( Plasmid )    pX459
# Promoter:  U6
# Resistance Markers:  Puromycin
# Experiment Host:  Human cell lines
# Transfected?  Y
# Transfected into:  K562, HepG2, lymphoblastoid cell lines
# Admin H/A? N
#
# ( Plasmid )    pX549
# Promoter:  Cbh
# Resistance Markers:  Puromycin
# Experiment Host:  Human and mouse hematopoietic cells and cell lines
# Transfected?  Y
# Transfected into:  Human and mouse cells
# Admin H/A? N
#
# ( Plasmid )    This is not a vector. It is a library of CRISPR/Cas9 ribonucleoprotein particles
# Promoter:  none
# Resistance Markers:  none
# Experiment Host:  Human and mouse hematopoietic cells and cell lines
# Transfected?  Y
# Transfected into:  Human and mouse hematopoietic cells and cell lines
# Admin H/A? N
#
# ( Plasmid )    TRIPZ
# Promoter:  Tet-response element
# Resistance Markers:  Puromycin
# Experiment Host:  Human cells
# Transfected?  Y
# Transfected into:  Human cells
# Admin H/A? N
#
# ( Cultured Cells )    K562, HeLa, HEK293T, HL60, Kasumi, Mono7, UoCM1, MonoMac, NB4, U937, ML-2
#
# ( Human Material )    Cord blood hematopoietic stem cells, leukemia cells
# No IRB:  No Data
#
#
#
# DNA
# A library of CRISPR/Cas9 ribonucleoprotein particles targeting all known mouse and human genes
# Function:  Gene editing
# Species derived from:  Synthetic
# Oncogene:  Y
#
# A library of DNA encoding Crispr guide RNA targeting every gene, including known oncogenes and tumor suppressors
# Function:  Express guide RNA to target Cas9-mediated gene deletions
# Species derived from:  synthesized
# Oncogene:  Y
#
# Cux1, all isoforms, and deletion mutants
# Function:  Transcription factor
# Species derived from:  Mouse
# Oncogene:  Y
#
# CUX1, all isoforms, and deletion mutants
# Function:  Transcription factor
# Species derived from:  Human
# Oncogene:  Y
#
# Every gene, including known oncogenes and tumor suppressors
# Function:  Regulation of cell growth and differentiation
# Species derived from:  Human
# Oncogene:  Y
#
# Every gene, including known oncogenes and tumor suppressors
# Function:  Regulation of cell growth and differentiation
# Species derived from:  Mouse
# Oncogene:  Y
#
# mCherry with CUX1 homology arms
# Function:  tag endogenous Cux1 with mCherry to generate reporter mouse
# Species derived from:  synthetic
# Oncogene:  N
#
# shRNA targeting all known oncogenes and tumor suppressors (human and mouse)
# Function:  Regulation of cell growth and differentiation
# Species derived from:  Recombinant
# Oncogene:  Y
#
# shRNA targeting human CUX1
# Function:  Knockdown target genes
# Species derived from:  Synthesized
# Oncogene:  Y
#
# shRNA targeting murine CUX1
# Function:  Knockdown target genes
# Species derived from:  Synthesized
# Oncogene:  N
#
#
#
# Room Locations
# 5235  Knapp Center for Biomedical Discovery (KCBD)
# Use:  Wet Lab: Single P.I., Not Shared
#
# 5235  Knapp Center for Biomedical Discovery (KCBD)
# Use:  Wet Lab: Single P.I., Not Shared
#
# 5240D, 5240F  Knapp Center for Biomedical Discovery (KCBD)
# Use:  Wet Lab: Multi-P.I., Shared Lab
#
# No Data  Knapp Center for Biomedical Discovery (KCBD)
# Use:  Animal Procedure Lab
#
# No Data  Knapp Center for Biomedical Discovery (KCBD)
# Use:  Animal Quarters: Barrier
#
#
#
# Biosafet Cabinets
# Thermo Scientific	1300 Series AII
# Class II, Type A2	 Last Cert:  7/19/17
# Room:  5235
# Knapp Center for Biomedical Discovery (KCBD)
# Serial #:  150254-367
#
# Thermo Scientific	1300 Series AII
# Class II, Type A2	 Last Cert:  7/19/17
# Room:  5235
# Knapp Center for Biomedical Discovery (KCBD)
# Serial #:  150254-368
#
#
#
# Animal Administration
# Plasmid vector - PBSKII
# Animal:  MOUSE 	 Shed?  N
# Max Dose:  1 ng 	Num Doses:  one time 	Frequency:  one time
# Transport?  No Data 	IACUC:  72381-1
#
# Transfected cell - Human hematopoietic stem cells - CRISPR/Cas9 ribonucleoprotein particles
# Animal:  MOUSE 	 Shed?  N
# Max Dose:  5-20x10^5 transfected cells 	Num Doses:  1 	Frequency:  one time
# Transport?  No Data 	IACUC:  72381-1
#
# Transfected cell - Mouse hematopoietic stem cells - CRISPR/Cas9 ribonucleoprotein particles
# Animal:  MOUSE 	 Shed?  N
# Max Dose:  5-20x10^5 transfected cells 	Num Doses:  one 	Frequency:  one time
# Transport?  No Data 	IACUC:  72381-1
#
# Virally transduced cell - Human primary hematopoietic cells - Library contains all genes including all known oncogenes and tumor suppressors or shRNA targeting those genes - Lentivirus
# Animal:  MOUSE 	 Shed?  N
# Max Dose:  5-20x10^5 transduced cells 	Num Doses:  one 	Frequency:  one
# Transport?  No Data 	IACUC:  72381-1
#
# Virally transduced cell - Murine primary hematopoietic cells - A library of all genes, including known oncogenes and proto-oncogenes, or shRNA targeting those genes - Lentivirus and/or Retrovirus
# Animal:  MOUSE 	 Shed?  N
# Max Dose:  5-20x10^5 transduced cells 	Num Doses:  one 	Frequency:  one
# Transport?  No Data 	IACUC:  72381-1
